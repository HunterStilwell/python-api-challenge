# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 602

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?appID={weather_api_key}&units=metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        time.sleep(2)

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | yuzhno-kurilsk
# Processing Record 3 of Set 1 | arteche
# Processing Record 4 of Set 1 | tiksi
# Processing Record 5 of Set 1 | vilyuchinsk
# Processing Record 6 of Set 1 | kharp
# Processing Record 7 of Set 1 | rabo de peixe
# Processing Record 8 of Set 1 | egilsstadir
# Processing Record 9 of Set 1 | el calafate
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | bishkek
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | severo-yeniseyskiy
# Processing Record 16 of Set 1 | codrington
# Processing Record 17 of Set 1 | monte alegre
# Processing Record 18 of Set 1 | northam
# Processing Record 19 of Set 1 | nuku'alofa
# Processing Record 20 of Set 1 | papao
# Processing Record 21 of Set 1 | quellon
# Processing Record 22 of Set 1 | tazacorte
# Processing Record 23 of Set 1 | vila velha
# Processing Record 24 of Set 1 | kingston
# Processing Record 25 of Set 1 | jean-rabel
# Processing Record 26 of Set 1 | crane
# Processing Record 27 of Set 1 | ixtapa
# Processing Record 28 of Set 1 | grytviken
# Processing Record 29 of Set 1 | kavaratti
# Processing Record 30 of Set 1 | antsiranana
# Processing Record 31 of Set 1 | mogilno
# Processing Record 32 of Set 1 | bardaskan
# City not found. Skipping...
# Processing Record 33 of Set 1 | aral
# Processing Record 34 of Set 1 | kargasok
# Processing Record 35 of Set 1 | guerrero negro
# Processing Record 36 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 37 of Set 1 | adamstown
# Processing Record 38 of Set 1 | mafeteng
# Processing Record 39 of Set 1 | maroua
# Processing Record 40 of Set 1 | meadow lakes
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | constantia
# Processing Record 43 of Set 1 | whitehorse
# Processing Record 44 of Set 1 | kapa'a
# Processing Record 45 of Set 1 | ratnagiri
# Processing Record 46 of Set 1 | west island
# Processing Record 47 of Set 1 | iqaluit
# Processing Record 48 of Set 1 | invercargill
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | isafjordur
# Processing Record 0 of Set 2 | naze
# Processing Record 1 of Set 2 | udachny
# Processing Record 2 of Set 2 | kununurra
# Processing Record 3 of Set 2 | fort bragg
# Processing Record 4 of Set 2 | qaqortoq
# Processing Record 5 of Set 2 | longyearbyen
# Processing Record 6 of Set 2 | birjand
# Processing Record 7 of Set 2 | puerto natales
# Processing Record 8 of Set 2 | bandarbeyla
# Processing Record 9 of Set 2 | olonkinbyen
# Processing Record 10 of Set 2 | tawau
# Processing Record 11 of Set 2 | papatowai
# Processing Record 12 of Set 2 | college
# Processing Record 13 of Set 2 | lompoc
# Processing Record 14 of Set 2 | pandan
# Processing Record 15 of Set 2 | aykhal
# Processing Record 16 of Set 2 | ribeira brava
# Processing Record 17 of Set 2 | guangming
# Processing Record 18 of Set 2 | utrik
# Processing Record 19 of Set 2 | hawaiian paradise park
# Processing Record 20 of Set 2 | sanctuary point
# Processing Record 21 of Set 2 | greymouth
# Processing Record 22 of Set 2 | diu
# Processing Record 23 of Set 2 | blackmans bay
# Processing Record 24 of Set 2 | cabo san lucas
# Processing Record 25 of Set 2 | stanley
# Processing Record 26 of Set 2 | argayash
# Processing Record 27 of Set 2 | geraldton
# Processing Record 28 of Set 2 | kavieng
# Processing Record 29 of Set 2 | lebu
# Processing Record 30 of Set 2 | vernon
# Processing Record 31 of Set 2 | edinburgh of the seven seas
# Processing Record 32 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 33 of Set 2 | aasiaat
# Processing Record 34 of Set 2 | ola
# Processing Record 35 of Set 2 | villa gesell
# Processing Record 36 of Set 2 | buka
# Processing Record 37 of Set 2 | itamaraca
# Processing Record 38 of Set 2 | skovorodino
# Processing Record 39 of Set 2 | dudinka
# Processing Record 40 of Set 2 | penza
# Processing Record 41 of Set 2 | guarapari
# Processing Record 42 of Set 2 | port alfred
# Processing Record 43 of Set 2 | sesheke
# Processing Record 44 of Set 2 | anadyr
# Processing Record 45 of Set 2 | ushuaia
# Processing Record 46 of Set 2 | chhatarpur
# Processing Record 47 of Set 2 | thompson
# Processing Record 48 of Set 2 | vila franca do campo
# Processing Record 49 of Set 2 | kolonia town
# Processing Record 0 of Set 3 | yangor
# City not found. Skipping...
# Processing Record 1 of Set 3 | remire-montjoly
# Processing Record 2 of Set 3 | margaret river
# Processing Record 3 of Set 3 | la ronge
# Processing Record 4 of Set 3 | alice
# Processing Record 5 of Set 3 | kapuskasing
# Processing Record 6 of Set 3 | beau vallon
# Processing Record 7 of Set 3 | reggane
# Processing Record 8 of Set 3 | cooper's town
# Processing Record 9 of Set 3 | waitangi
# Processing Record 10 of Set 3 | paita
# Processing Record 11 of Set 3 | aqadyr
# Processing Record 12 of Set 3 | berezovyy
# Processing Record 13 of Set 3 | pocatello
# Processing Record 14 of Set 3 | nagarpur
# Processing Record 15 of Set 3 | avsallar
# Processing Record 16 of Set 3 | steinkjer
# Processing Record 17 of Set 3 | chonchi
# Processing Record 18 of Set 3 | kollam
# Processing Record 19 of Set 3 | nowy dwor gdanski
# Processing Record 20 of Set 3 | ilulissat
# Processing Record 21 of Set 3 | vadso
# Processing Record 22 of Set 3 | najran
# Processing Record 23 of Set 3 | port mathurin
# Processing Record 24 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 25 of Set 3 | creswell
# Processing Record 26 of Set 3 | new cairo
# City not found. Skipping...
# Processing Record 27 of Set 3 | jeremie
# Processing Record 28 of Set 3 | east london
# Processing Record 29 of Set 3 | tura
# Processing Record 30 of Set 3 | acarau
# Processing Record 31 of Set 3 | st. john's
# Processing Record 32 of Set 3 | hamilton
# Processing Record 33 of Set 3 | xilin hot
# Processing Record 34 of Set 3 | takamaka
# City not found. Skipping...
# Processing Record 35 of Set 3 | khoyniki
# Processing Record 36 of Set 3 | yanbu
# Processing Record 37 of Set 3 | wailua homesteads
# Processing Record 38 of Set 3 | shingu
# Processing Record 39 of Set 3 | lihue
# Processing Record 40 of Set 3 | brisas de zicatela
# Processing Record 41 of Set 3 | roma
# Processing Record 42 of Set 3 | yinchuan
# Processing Record 43 of Set 3 | sodankyla
# Processing Record 44 of Set 3 | suva
# Processing Record 45 of Set 3 | camabatela
# Processing Record 46 of Set 3 | itoman
# Processing Record 47 of Set 3 | nantucket
# Processing Record 48 of Set 3 | yur'yevets
# Processing Record 49 of Set 3 | souillac
# Processing Record 0 of Set 4 | verkhnevilyuysk
# Processing Record 1 of Set 4 | pagar alam
# Processing Record 2 of Set 4 | umm kaddadah
# Processing Record 3 of Set 4 | lorengau
# Processing Record 4 of Set 4 | okhotsk
# Processing Record 5 of Set 4 | saipan
# Processing Record 6 of Set 4 | bilibino
# Processing Record 7 of Set 4 | nuuk
# Processing Record 8 of Set 4 | dalian
# Processing Record 9 of Set 4 | cascais
# Processing Record 10 of Set 4 | badger
# Processing Record 11 of Set 4 | sagalo
# City not found. Skipping...
# Processing Record 12 of Set 4 | kisasa
# City not found. Skipping...
# Processing Record 13 of Set 4 | tortoli
# Processing Record 14 of Set 4 | ribeira grande
# Processing Record 15 of Set 4 | valparaiso
# Processing Record 16 of Set 4 | waat
# Processing Record 17 of Set 4 | saynshand
# Processing Record 18 of Set 4 | pisco
# Processing Record 19 of Set 4 | barcelos
# Processing Record 20 of Set 4 | astrakhan
# Processing Record 21 of Set 4 | namibe
# Processing Record 22 of Set 4 | tzucacab
# Processing Record 23 of Set 4 | san patricio
# Processing Record 24 of Set 4 | nishinoomote
# Processing Record 25 of Set 4 | labrador city
# Processing Record 26 of Set 4 | male
# Processing Record 27 of Set 4 | emerald
# Processing Record 28 of Set 4 | miyanoura
# City not found. Skipping...
# Processing Record 29 of Set 4 | turpan
# Processing Record 30 of Set 4 | kill devil hills
# Processing Record 31 of Set 4 | khandyga
# Processing Record 32 of Set 4 | cidreira
# Processing Record 33 of Set 4 | bikenibeu village
# Processing Record 34 of Set 4 | mount pearl
# Processing Record 35 of Set 4 | hadibu
# Processing Record 36 of Set 4 | anori
# Processing Record 37 of Set 4 | iskateley
# Processing Record 38 of Set 4 | huarmey
# Processing Record 39 of Set 4 | susuman
# Processing Record 40 of Set 4 | jhingergacha
# Processing Record 41 of Set 4 | vorgashor
# Processing Record 42 of Set 4 | kalmunai
# Processing Record 43 of Set 4 | klyuchi
# Processing Record 44 of Set 4 | parabel'
# Processing Record 45 of Set 4 | mineiros
# Processing Record 46 of Set 4 | axim
# Processing Record 47 of Set 4 | mogocha
# Processing Record 48 of Set 4 | cooma
# Processing Record 49 of Set 4 | farafangana
# Processing Record 0 of Set 5 | yatou
# Processing Record 1 of Set 5 | arno
# Processing Record 2 of Set 5 | bethel
# Processing Record 3 of Set 5 | las heras
# Processing Record 4 of Set 5 | mata-utu
# Processing Record 5 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 6 of Set 5 | basco
# Processing Record 7 of Set 5 | afaahiti
# Processing Record 8 of Set 5 | tordesillas
# Processing Record 9 of Set 5 | nagqu
# Processing Record 10 of Set 5 | torbat-e heydariyeh
# Processing Record 11 of Set 5 | atafu village
# Processing Record 12 of Set 5 | biltine
# Processing Record 13 of Set 5 | waingapu
# Processing Record 14 of Set 5 | kruisfontein
# Processing Record 15 of Set 5 | ta`u
# Processing Record 16 of Set 5 | port moresby
# Processing Record 17 of Set 5 | coroata
# Processing Record 18 of Set 5 | carnarvon
# Processing Record 19 of Set 5 | nova sintra
# Processing Record 20 of Set 5 | masku
# Processing Record 21 of Set 5 | benguela
# Processing Record 22 of Set 5 | alaghsas
# Processing Record 23 of Set 5 | midoun
# Processing Record 24 of Set 5 | kalemie
# Processing Record 25 of Set 5 | amga
# Processing Record 26 of Set 5 | eyl
# Processing Record 27 of Set 5 | aketi
# Processing Record 28 of Set 5 | nephi
# Processing Record 29 of Set 5 | pimenta bueno
# Processing Record 30 of Set 5 | moussoro
# Processing Record 31 of Set 5 | happy valley-goose bay
# Processing Record 32 of Set 5 | gwio kura
# Processing Record 33 of Set 5 | hithadhoo
# Processing Record 34 of Set 5 | luderitz
# Processing Record 35 of Set 5 | kundiawa
# Processing Record 36 of Set 5 | kodiak
# Processing Record 37 of Set 5 | nelidovo
# Processing Record 38 of Set 5 | pecanha
# Processing Record 39 of Set 5 | saint joseph
# Processing Record 40 of Set 5 | kedougou
# Processing Record 41 of Set 5 | paka
# Processing Record 42 of Set 5 | kenai
# Processing Record 43 of Set 5 | fale old settlement
# Processing Record 44 of Set 5 | las lomitas
# Processing Record 45 of Set 5 | tadine
# Processing Record 46 of Set 5 | pakur
# Processing Record 47 of Set 5 | callao
# Processing Record 48 of Set 5 | cutlerville
# Processing Record 49 of Set 5 | pariaman
# Processing Record 0 of Set 6 | sabang
# Processing Record 1 of Set 6 | kudahuvadhoo
# Processing Record 2 of Set 6 | punta arenas
# Processing Record 3 of Set 6 | laguna
# Processing Record 4 of Set 6 | alofi
# Processing Record 5 of Set 6 | rongelap
# Processing Record 6 of Set 6 | walvis bay
# Processing Record 7 of Set 6 | saint-philippe
# Processing Record 8 of Set 6 | hola
# Processing Record 9 of Set 6 | weno
# Processing Record 10 of Set 6 | praia da vitoria
# Processing Record 11 of Set 6 | kailua-kona
# Processing Record 12 of Set 6 | tepalcatepec
# Processing Record 13 of Set 6 | panacan
# Processing Record 14 of Set 6 | tazovsky
# Processing Record 15 of Set 6 | berber
# Processing Record 16 of Set 6 | brookings
# Processing Record 17 of Set 6 | jendouba
# Processing Record 18 of Set 6 | bukama
# Processing Record 19 of Set 6 | wewak
# Processing Record 20 of Set 6 | margate
# Processing Record 21 of Set 6 | lospalos
# Processing Record 22 of Set 6 | devils lake
# Processing Record 23 of Set 6 | bamyan
# Processing Record 24 of Set 6 | chatel-guyon
# Processing Record 25 of Set 6 | hermanus
# Processing Record 26 of Set 6 | caleta de carquin
# Processing Record 27 of Set 6 | deqen
# Processing Record 28 of Set 6 | ust-nera
# Processing Record 29 of Set 6 | ancud
# Processing Record 30 of Set 6 | ciudad lazaro cardenas
# Processing Record 31 of Set 6 | cuyo
# Processing Record 32 of Set 6 | blagoveshchenka
# Processing Record 33 of Set 6 | aykol
# City not found. Skipping...
# Processing Record 34 of Set 6 | george town
# Processing Record 35 of Set 6 | puerto cabezas
# Processing Record 36 of Set 6 | smithers
# Processing Record 37 of Set 6 | hard bargain
# Processing Record 38 of Set 6 | loralai
# Processing Record 39 of Set 6 | talnakh
# Processing Record 40 of Set 6 | canutama
# Processing Record 41 of Set 6 | i-n-salah
# Processing Record 42 of Set 6 | bryne
# Processing Record 43 of Set 6 | magadan
# Processing Record 44 of Set 6 | queenstown
# Processing Record 45 of Set 6 | kourou
# Processing Record 46 of Set 6 | guanare
# Processing Record 47 of Set 6 | molchanovo
# Processing Record 48 of Set 6 | estevan
# Processing Record 49 of Set 6 | atherton
# Processing Record 0 of Set 7 | orlov
# Processing Record 1 of Set 7 | shagonar
# Processing Record 2 of Set 7 | barbacoas
# Processing Record 3 of Set 7 | binghamton
# Processing Record 4 of Set 7 | wamba
# Processing Record 5 of Set 7 | quiindy
# Processing Record 6 of Set 7 | priargunsk
# Processing Record 7 of Set 7 | balaklava
# Processing Record 8 of Set 7 | sitka
# Processing Record 9 of Set 7 | phongsali
# Processing Record 10 of Set 7 | revda
# Processing Record 11 of Set 7 | mccook
# Processing Record 12 of Set 7 | arraial do cabo
# Processing Record 13 of Set 7 | anibare
# City not found. Skipping...
# Processing Record 14 of Set 7 | mambolo
# Processing Record 15 of Set 7 | enewetak
# Processing Record 16 of Set 7 | mount gambier
# Processing Record 17 of Set 7 | marka
# Processing Record 18 of Set 7 | amos
# Processing Record 19 of Set 7 | maceio
# Processing Record 20 of Set 7 | maardu
# Processing Record 21 of Set 7 | nar'yan-mar
# Processing Record 22 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 23 of Set 7 | champerico
# Processing Record 24 of Set 7 | port elizabeth
# Processing Record 25 of Set 7 | dunedin
# Processing Record 26 of Set 7 | sao vicente
# Processing Record 27 of Set 7 | virginia
# Processing Record 28 of Set 7 | houlton
# Processing Record 29 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 30 of Set 7 | kontcha
# Processing Record 31 of Set 7 | tekkali
# Processing Record 32 of Set 7 | troitsko-pechorsk
# Processing Record 33 of Set 7 | port douglas
# Processing Record 34 of Set 7 | herceg novi
# Processing Record 35 of Set 7 | tolanaro
# Processing Record 36 of Set 7 | san antonio de pale
# Processing Record 37 of Set 7 | riachao das neves
# Processing Record 38 of Set 7 | port lincoln
# Processing Record 39 of Set 7 | qamdo
# Processing Record 40 of Set 7 | ambovombe
# Processing Record 41 of Set 7 | santa cruz
# Processing Record 42 of Set 7 | freetown
# Processing Record 43 of Set 7 | elizabeth city
# Processing Record 44 of Set 7 | ciudad camilo cienfuegos
# City not found. Skipping...
# Processing Record 45 of Set 7 | labytnangi
# Processing Record 46 of Set 7 | lima
# Processing Record 47 of Set 7 | linares
# Processing Record 48 of Set 7 | barclayville
# Processing Record 49 of Set 7 | kristinestad
# Processing Record 0 of Set 8 | moyale
# Processing Record 1 of Set 8 | cam ranh
# Processing Record 2 of Set 8 | ad dabbah
# Processing Record 3 of Set 8 | prince rupert
# Processing Record 4 of Set 8 | sungailiat
# Processing Record 5 of Set 8 | kristiansund
# Processing Record 6 of Set 8 | south sioux city
# Processing Record 7 of Set 8 | georgetown
# Processing Record 8 of Set 8 | changsha
# Processing Record 9 of Set 8 | gorontalo
# Processing Record 10 of Set 8 | bodaybo
# Processing Record 11 of Set 8 | suzhou
# Processing Record 12 of Set 8 | sarmiento
# Processing Record 13 of Set 8 | dwarka
# Processing Record 14 of Set 8 | palmer
# Processing Record 15 of Set 8 | hotan
# Processing Record 16 of Set 8 | puerto deseado
# Processing Record 17 of Set 8 | woods creek
# Processing Record 18 of Set 8 | yanchep
# Processing Record 19 of Set 8 | tsiombe
# Processing Record 20 of Set 8 | xinyuan
# Processing Record 21 of Set 8 | tremonton
# Processing Record 22 of Set 8 | graaff-reinet
# Processing Record 23 of Set 8 | carry-le-rouet
# Processing Record 24 of Set 8 | amursk
# Processing Record 25 of Set 8 | inhambane
# Processing Record 26 of Set 8 | haiku-pauwela
# Processing Record 27 of Set 8 | minas de marcona
# Processing Record 28 of Set 8 | qulsary
# Processing Record 29 of Set 8 | alice springs
# Processing Record 30 of Set 8 | sao felix do xingu
# Processing Record 31 of Set 8 | prado
# Processing Record 32 of Set 8 | comodoro rivadavia
# Processing Record 33 of Set 8 | acapulco de juarez
# Processing Record 34 of Set 8 | ringkobing
# Processing Record 35 of Set 8 | taro
# Processing Record 36 of Set 8 | narrabri
# Processing Record 37 of Set 8 | yamada
# Processing Record 38 of Set 8 | gisborne
# Processing Record 39 of Set 8 | sungai penuh
# Processing Record 40 of Set 8 | san martin de los andes
# Processing Record 41 of Set 8 | puerto armuelles
# Processing Record 42 of Set 8 | dhidhdhoo
# Processing Record 43 of Set 8 | calama
# Processing Record 44 of Set 8 | mendota
# Processing Record 45 of Set 8 | bulayevo
# Processing Record 46 of Set 8 | tevriz
# Processing Record 47 of Set 8 | camana
# Processing Record 48 of Set 8 | sovetskaya gavan'
# Processing Record 49 of Set 8 | al muwayh
# Processing Record 0 of Set 9 | aioun
# Processing Record 1 of Set 9 | hede
# Processing Record 2 of Set 9 | isangel
# Processing Record 3 of Set 9 | portland
# Processing Record 4 of Set 9 | ketchikan
# Processing Record 5 of Set 9 | arkhangel'sk
# Processing Record 6 of Set 9 | altai
# Processing Record 7 of Set 9 | mournies
# Processing Record 8 of Set 9 | kingscliff
# Processing Record 9 of Set 9 | flying fish cove
# Processing Record 10 of Set 9 | kayangel
# Processing Record 11 of Set 9 | frenda
# Processing Record 12 of Set 9 | the pas
# Processing Record 13 of Set 9 | nema
# Processing Record 14 of Set 9 | beyneu
# Processing Record 15 of Set 9 | nemuro
# Processing Record 16 of Set 9 | copiapo
# Processing Record 17 of Set 9 | puerto penasco
# Processing Record 18 of Set 9 | sorong
# Processing Record 19 of Set 9 | aqsay
# Processing Record 20 of Set 9 | massenya
# Processing Record 21 of Set 9 | conception bay south
# Processing Record 22 of Set 9 | mulchen
# Processing Record 23 of Set 9 | bouza
# Processing Record 24 of Set 9 | yagry
# City not found. Skipping...
# Processing Record 25 of Set 9 | ust'-ilimsk
# Processing Record 26 of Set 9 | awjilah
# Processing Record 27 of Set 9 | rikaze
# Processing Record 28 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 29 of Set 9 | phan rang-thap cham
# Processing Record 30 of Set 9 | choibalsan
# Processing Record 31 of Set 9 | west end village
# City not found. Skipping...
# Processing Record 32 of Set 9 | tshabong
# Processing Record 33 of Set 9 | nanning
# Processing Record 34 of Set 9 | abepura
# Processing Record 35 of Set 9 | sandnessjoen
# Processing Record 36 of Set 9 | kokkola
# Processing Record 37 of Set 9 | ciudad gustavo diaz ordaz
# Processing Record 38 of Set 9 | tahoua
# Processing Record 39 of Set 9 | boa vista
# Processing Record 40 of Set 9 | salekhard
# Processing Record 41 of Set 9 | karratha
# Processing Record 42 of Set 9 | constitucion
# Processing Record 43 of Set 9 | saint-francois
# Processing Record 44 of Set 9 | pampa del indio
# Processing Record 45 of Set 9 | thinadhoo
# Processing Record 46 of Set 9 | sisimiut
# Processing Record 47 of Set 9 | grand falls-windsor
# Processing Record 48 of Set 9 | daruvar
# Processing Record 49 of Set 9 | quelimane
# Processing Record 0 of Set 10 | polyarnyy
# Processing Record 1 of Set 10 | keflavik
# Processing Record 2 of Set 10 | bovalino
# Processing Record 3 of Set 10 | portales
# Processing Record 4 of Set 10 | kuching
# Processing Record 5 of Set 10 | nogliki
# Processing Record 6 of Set 10 | acajutla
# Processing Record 7 of Set 10 | new norfolk
# Processing Record 8 of Set 10 | sonsorol village
# City not found. Skipping...
# Processing Record 9 of Set 10 | bokakhat
# Processing Record 10 of Set 10 | 'ali al gharbi
# Processing Record 11 of Set 10 | lubang
# Processing Record 12 of Set 10 | richards bay
# Processing Record 13 of Set 10 | saint-pierre
# Processing Record 14 of Set 10 | kafarati
# Processing Record 15 of Set 10 | tshikapa
# Processing Record 16 of Set 10 | nanao
# Processing Record 17 of Set 10 | caleta olivia
# Processing Record 18 of Set 10 | napili-honokowai
# Processing Record 19 of Set 10 | mwene-ditu
# Processing Record 20 of Set 10 | prince albert
# Processing Record 21 of Set 10 | vilyuysk
# Processing Record 22 of Set 10 | phon charoen
# Processing Record 23 of Set 10 | adrar
# Processing Record 24 of Set 10 | ghat
# Processing Record 25 of Set 10 | las cruces
# Processing Record 26 of Set 10 | sofifi
# City not found. Skipping...
# Processing Record 27 of Set 10 | cockburn town
# Processing Record 28 of Set 10 | argo
# Processing Record 29 of Set 10 | manjeshvar
# Processing Record 30 of Set 10 | chibougamau
# Processing Record 31 of Set 10 | espargos
# City not found. Skipping...
# Processing Record 32 of Set 10 | betio village
# Processing Record 33 of Set 10 | sinabang
# Processing Record 34 of Set 10 | vrsac
# Processing Record 35 of Set 10 | cargados carajos
# City not found. Skipping...
# Processing Record 36 of Set 10 | zafar
# Processing Record 37 of Set 10 | chernyshevskiy
# Processing Record 38 of Set 10 | jaisalmer
# Processing Record 39 of Set 10 | lubbenau
# Processing Record 40 of Set 10 | 'ohonua
# City not found. Skipping...
# Processing Record 41 of Set 10 | santiago de cao
# Processing Record 42 of Set 10 | arish
# Processing Record 43 of Set 10 | pochinok
# Processing Record 44 of Set 10 | newport
# Processing Record 45 of Set 10 | okha
# Processing Record 46 of Set 10 | homer
# Processing Record 47 of Set 10 | pikeville
# Processing Record 48 of Set 10 | grand-lahou
# Processing Record 49 of Set 10 | nyurba
# Processing Record 0 of Set 11 | middlebury (village)
# Processing Record 1 of Set 11 | cadale
# Processing Record 2 of Set 11 | balqash
# Processing Record 3 of Set 11 | kirensk
# Processing Record 4 of Set 11 | shahrak-e pabedana
# City not found. Skipping...
# Processing Record 5 of Set 11 | westport
# Processing Record 6 of Set 11 | flin flon
# Processing Record 7 of Set 11 | alytus
# Processing Record 8 of Set 11 | yarmouth
# Processing Record 9 of Set 11 | selfoss
# Processing Record 10 of Set 11 | howrah
# Processing Record 11 of Set 11 | borivli
# Processing Record 12 of Set 11 | rundu
# Processing Record 13 of Set 11 | virpur
# Processing Record 14 of Set 11 | sur
# Processing Record 15 of Set 11 | rapar
# Processing Record 16 of Set 11 | iwon-up
# Processing Record 17 of Set 11 | chudovo
# Processing Record 18 of Set 11 | mammoth lakes
# Processing Record 19 of Set 11 | laminusa
# Processing Record 20 of Set 11 | yangirabot
# Processing Record 21 of Set 11 | tejen
# Processing Record 22 of Set 11 | abu dhabi
# Processing Record 23 of Set 11 | loango
# Processing Record 24 of Set 11 | bamboo flat
# Processing Record 25 of Set 11 | chuzhou
# Processing Record 26 of Set 11 | bundaberg north
# Processing Record 27 of Set 11 | mouila
# Processing Record 28 of Set 11 | igarka
# Processing Record 29 of Set 11 | porto novo
# Processing Record 30 of Set 11 | puerto san jose
# Processing Record 31 of Set 11 | taltal
# Processing Record 32 of Set 11 | halifax
# Processing Record 33 of Set 11 | dengzhou
# Processing Record 34 of Set 11 | saksaul'skiy
# City not found. Skipping...
# Processing Record 35 of Set 11 | zheleznodorozhnyy
# Processing Record 36 of Set 11 | pudozh
# Processing Record 37 of Set 11 | puke
# Processing Record 38 of Set 11 | khovd
# Processing Record 39 of Set 11 | fortuna
# Processing Record 40 of Set 11 | raja
# Processing Record 41 of Set 11 | kone
# Processing Record 42 of Set 11 | chengde
# Processing Record 43 of Set 11 | ljusdal
# Processing Record 44 of Set 11 | sao paulo de olivenca
# Processing Record 45 of Set 11 | sonepur
# Processing Record 46 of Set 11 | tralee
# Processing Record 47 of Set 11 | jiagedaqi
# Processing Record 48 of Set 11 | saint-priest-en-jarez
# Processing Record 49 of Set 11 | natividad
# Processing Record 0 of Set 12 | humaita
# Processing Record 1 of Set 12 | syumsi
# Processing Record 2 of Set 12 | la cruz
# Processing Record 3 of Set 12 | dadukou
# Processing Record 4 of Set 12 | hun
# Processing Record 5 of Set 12 | al artawiyah
# Processing Record 6 of Set 12 | gusinje
# Processing Record 7 of Set 12 | lesozavodsk
# Processing Record 8 of Set 12 | as sulayyil
# Processing Record 9 of Set 12 | yaren
# Processing Record 10 of Set 12 | san juan de miraflores
# Processing Record 11 of Set 12 | taungdwingyi
# Processing Record 12 of Set 12 | tlahualilo de zaragoza
# Processing Record 13 of Set 12 | chongwe
# Processing Record 14 of Set 12 | abqaiq
# Processing Record 15 of Set 12 | esmeraldas
# Processing Record 16 of Set 12 | jingdezhen
# Processing Record 17 of Set 12 | berdigestyakh
# Processing Record 18 of Set 12 | tucurui
# Processing Record 19 of Set 12 | wolczyn
# Processing Record 20 of Set 12 | puerto baquerizo moreno
# Processing Record 21 of Set 12 | miura
# Processing Record 22 of Set 12 | waliso
# Processing Record 23 of Set 12 | opuwo
# Processing Record 24 of Set 12 | turochak
# Processing Record 25 of Set 12 | ocean city
# Processing Record 26 of Set 12 | madhogarh
# Processing Record 27 of Set 12 | san carlos de bariloche
# Processing Record 28 of Set 12 | semera
# Processing Record 29 of Set 12 | sainte-adele
# Processing Record 30 of Set 12 | poli
# Processing Record 31 of Set 12 | idaho falls
# Processing Record 32 of Set 12 | jayapura
# Processing Record 33 of Set 12 | oranjemund
# Processing Record 34 of Set 12 | christchurch
# Processing Record 35 of Set 12 | mhamid
# Processing Record 36 of Set 12 | chania
# Processing Record 37 of Set 12 | saint-joseph
# Processing Record 38 of Set 12 | mossendjo
# Processing Record 39 of Set 12 | gamay
# Processing Record 40 of Set 12 | sacramento
# Processing Record 41 of Set 12 | paphos
# Processing Record 42 of Set 12 | taroa
# Processing Record 43 of Set 12 | kalachinsk
# Processing Record 44 of Set 12 | tommot
# Processing Record 45 of Set 12 | terrace
# Processing Record 46 of Set 12 | kudymkar
# Processing Record 47 of Set 12 | fort st. john
# Processing Record 48 of Set 12 | murghob
# Processing Record 49 of Set 12 | lagos
# Processing Record 0 of Set 13 | howard springs
# Processing Record 1 of Set 13 | soio
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167      1.92        70         100
# 1     yuzhno-kurilsk  44.0306  145.8556      7.99        76           4
# 2            arteche  12.2645  125.4048     27.39        87          95
# 3              tiksi  71.6872  128.8694    -16.81        99          74
# 4        vilyuchinsk  52.9306  158.4028      3.85        84          95
#
#    Wind Speed Country        Date
# 0       11.06      TF  1698623339
# 1        3.67      RU  1698623476
# 2        4.64      PH  1698623479
# 3        3.11      RU  1698623481
# 4        1.39      RU  1698623483

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      1.92        70         100
# 1           yuzhno-kurilsk  44.0306  145.8556      7.99        76           4
# 2                  arteche  12.2645  125.4048     27.39        87          95
# 3                    tiksi  71.6872  128.8694    -16.81        99          74
# 4              vilyuchinsk  52.9306  158.4028      3.85        84          95
#
#          Wind Speed Country        Date
# City_ID
# 0             11.06      TF  1698623339
# 1              3.67      RU  1698623476
# 2              4.64      PH  1698623479
# 3              3.11      RU  1698623481
# 4              1.39      RU  1698623483

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker='o', facecolors='steelblue', edgecolors='black')

# Incorporate the other graph properties
plt.title('City Latitude vs. Max Temperature (2023-10-29)')
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker='o', facecolors='steelblue', edgecolors='black')

# Incorporate the other graph properties
plt.title('City Latitude vs. Humidity (2023-10-29)')
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker='o', facecolors='steelblue', edgecolors='black')

# Incorporate the other graph properties
plt.title('City Latitude vs. Cloudiness (2023-10-29)')
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker='o', facecolors='steelblue', edgecolors='black')

# Incorporate the other graph properties
plt.title('City Latitude vs. Wind Speed (2023-10-29)')
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linearregress():
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    plt.plot(x_values,regress_values,"r-")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        yuzhno-kurilsk  44.0306  145.8556      7.99        76           4
# 2               arteche  12.2645  125.4048     27.39        87          95
# 3                 tiksi  71.6872  128.8694    -16.81        99          74
# 4           vilyuchinsk  52.9306  158.4028      3.85        84          95
# 5                 kharp  66.8014   65.8081    -14.30        98         100
#
#          Wind Speed Country        Date
# City_ID
# 1              3.67      RU  1698623476
# 2              4.64      PH  1698623479
# 3              3.11      RU  1698623481
# 4              1.39      RU  1698623483
# 5              1.38      RU  1698623486

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      1.92        70         100
# 8              el calafate -50.3408  -72.2768      4.62        57          65
# 11            puerto ayora  -0.7393  -90.3518     24.19        89          64
# 12                  avarua -21.2078 -159.7750     25.03        61          40
# 15              codrington -38.2667  141.9667     11.24        92          53
#
#          Wind Speed Country        Date
# City_ID
# 0             11.06      TF  1698623339
# 8              4.98      AR  1698623493
# 11             2.24      EC  1698623500
# 12             4.63      CK  1698623503
# 15             5.09      AU  1698623510

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
plt.scatter(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f"The r-value is: {rvalue}")
plt.plot(x_values,regress_values,"r-")
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(0,-10),fontsize=15,color="red")
plt.ylabel('Max Temp')
plt.xlabel("Latitude")
plt.show()
# Out:
# The r-value is: -0.8753751064193667

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
plt.scatter(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f"The r-value is: {rvalue}")
plt.plot(x_values,regress_values,"r-")
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-50,30),fontsize=15,color="red")
plt.ylabel('Max Temp')
plt.xlabel("Latitude")
plt.show()
# Out:
# The r-value is: 0.7708064046780292

# %% [markdown]
# **Discussion about the linear relationship:** In the nothern hemisphere, there is a strong negative correlation between latitude and max temperature. In the southern hemisphere, there is a strong positive correlation between latitude and max temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
plt.scatter(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f"The r-value is: {rvalue}")
plt.plot(x_values,regress_values,"r-")
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.ylabel('Humidity')
plt.xlabel("Latitude")
plt.show()
# Out:
# The r-value is: 0.1966293314043616

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
plt.scatter(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f"The r-value is: {rvalue}")
plt.plot(x_values,regress_values,"r-")
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.ylabel('Humidity')
plt.xlabel("Latitude")
plt.show()
# Out:
# The r-value is: 0.09094753606217149

# %% [markdown]
# **Discussion about the linear relationship:** In the northern hemisphere, there is a very weak positive correlation between latitude and humidity. In the southern hemisphere, there is a very weak positive correlation to no correlation between latitude and humidity

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
plt.scatter(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f"The r-value is: {rvalue}")
plt.plot(x_values,regress_values,"r-")
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.ylabel('Cloudiness')
plt.xlabel("Latitude")
plt.show()
# Out:
# The r-value is: 0.2011119828235101

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
plt.scatter(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f"The r-value is: {rvalue}")
plt.plot(x_values,regress_values,"r-")
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.ylabel('Cloudiness')
plt.xlabel("Latitude")
plt.show()
# Out:
# The r-value is: -0.010598019970468876

# %% [markdown]
# **Discussion about the linear relationship:** In the northern hemisphere, there is a very weak positive correlation between latitude and cloudiness. In the souhtern hemisphere, there is a very weak negative correlation to no correlation between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
plt.scatter(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f"The r-value is: {rvalue}")
plt.plot(x_values,regress_values,"r-")
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.ylabel('Wind Speed')
plt.xlabel("Latitude")
plt.show()
# Out:
# The r-value is: -0.004948379036585948

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
plt.scatter(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f"The r-value is: {rvalue}")
plt.plot(x_values,regress_values,"r-")
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.ylabel('Wind Speed')
plt.xlabel("Latitude")
plt.show()
# Out:
# The r-value is: -0.3445502284783075

# %% [markdown]
# **Discussion about the linear relationship:** In the northern hemisphere, there is a very weak negative correlation to no correlation between latitude and wind speed. In the southern hemisphere, there is a weak negative correlation between latitude and wind speed.
